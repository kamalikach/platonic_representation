# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fname = "./outputs/cifar_resnet_alexnet_35_2026-02-17_22-19-15.txt"

# %%
x, y = np.loadtxt(fname, delimiter=",", unpack=True)

plt.scatter(x[:1000], y[:1000])
plt.show()
